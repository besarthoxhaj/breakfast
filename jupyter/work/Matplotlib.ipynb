# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
simplePlt = plt.plot([1, 2, 3, 4])
print(simplePlt)
plt.show(simplePlt)

# %%
plt.figure(figsize=(30, 5))
plt.imshow(mpimg.imread('table.png'), interpolation='nearest', aspect='auto')
